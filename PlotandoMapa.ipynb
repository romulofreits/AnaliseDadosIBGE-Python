# %%
import pandas as pd
import plotly.offline as py
import plotly.graph_objs as go
import json
import plotly.express as px

# %%
#Vai renderiza todos os grafico em outra aba do firefox
import plotly.io as pio
pio.renderers.default = 'firefox'

# %%
#Base de dados

df = pd.read_csv('População por etnia_raca.csv')

with open('geojsonMunicipiosBrasil.json') as f:  
     counties = json.load(f)

# %%
nomeUF = ['Rondônia', 'Acre', 'Amazonas', 'Roraima', 'Pará', 'Amapá',
       'Tocantins', 'Maranhão', 'Piauí', 'Ceará', 'Rio Grande do Norte',
       'Paraíba', 'Pernambuco', 'Alagoas', 'Sergipe', 'Bahia',
       'Minas Gerais', 'Espírito Santo', 'Rio de Janeiro', 'São Paulo',
       'Paraná', 'Santa Catarina', 'Rio Grande do Sul',
       'Mato Grosso do Sul', 'Mato Grosso', 'Goiás', 'Distrito Federal']

quanti = {}

for i in nomeUF:
    value = dict(df[ df['Nome_UF'] == i  ][ 'Vencedor' ].value_counts())
    
    quanti[i] = value

# %%
df.head(10)
# Out:
#                     Município    Branca     Parda   Nome_UF       id Vencedor
# 0  Alta Floresta D'Oeste (RO)  0.424278  0.502993  Rondônia  1100015    Parda
# 1              Ariquemes (RO)  0.371468  0.525917  Rondônia  1100023    Parda
# 2                 Cabixi (RO)  0.466973  0.445588  Rondônia  1100031   Branca
# 3                 Cacoal (RO)  0.432586  0.480312  Rondônia  1100049    Parda
# 4             Cerejeiras (RO)  0.458512  0.465324  Rondônia  1100056    Parda
# 5      Colorado do Oeste (RO)  0.412942  0.502878  Rondônia  1100064    Parda
# 6             Corumbiara (RO)  0.376409  0.524536  Rondônia  1100072    Parda
# 7          Costa Marques (RO)  0.321319  0.579105  Rondônia  1100080    Parda
# 8        Espigão D'Oeste (RO)  0.455637  0.457029  Rondônia  1100098    Parda
# 9          Guajará-Mirim (RO)  0.214135  0.600394  Rondônia  1100106    Parda

# %%
#Plotando o grafico

fig = px.choropleth(df, 
                    locations='id', 
                    geojson = counties, 
                    color = 'Branca',
                    scope='south america',
                    hover_name='Município',
                    #color_continuous_scale="viridis"
                   #color_discrete_sequence = px.colors.qualitative.Antique
                   )

fig.update_layout(autosize=True,
                  margin = go.layout.Margin(l=0, r=0, t=0, b=0),
                  showlegend=False,
                )

fig.update_geos(fitbounds ='locations', 
                visible=False, 
                )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10280\1980785696.py in <module>
#      20                 )
#      21
# ---> 22 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\basedatatypes.py in show(self, *args, **kwargs)
#    3396         import plotly.io as pio
#    3397
# -> 3398         return pio.show(self, *args, **kwargs)
#    3399
#    3400     def to_json(self, *args, **kwargs):
#
# ~\anaconda3\lib\site-packages\plotly\io\_renderers.py in show(fig, renderer, validate, **kwargs)
#     401
#     402     # external renderers
# --> 403     renderers._perform_external_rendering(fig_dict, renderers_string=renderer, **kwargs)
#     404
#     405
#
# ~\anaconda3\lib\site-packages\plotly\io\_renderers.py in _perform_external_rendering(self, fig_dict, renderers_string, **kwargs)
#     338                         setattr(renderer, k, v)
# ...

# %%
#Parda
fig = px.choropleth_mapbox(df, geojson=counties, locations='id', color='Parda',
                           color_continuous_scale="Viridis",
                           mapbox_style="carto-positron",
                           zoom=3, 
                           center = {"lat": -10.704459239815383, "lon": -50.771587751708005},
                           opacity=0.5,
                           hover_name='Município'
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
#Branca
fig = px.choropleth_mapbox(df, geojson=counties, locations='id', color='Branca',
                           color_continuous_scale="Viridis",
                           mapbox_style="carto-positron",
                           zoom=3, 
                           center = {"lat": -10.704459239815383, "lon": -50.771587751708005},
                           opacity=0.5,
                           hover_name='Município'
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
#Vencedor
fig = px.choropleth_mapbox(df, geojson=counties, locations='id', color='Vencedor',
                           color_continuous_scale="Viridis",
                           mapbox_style="carto-positron",
                           zoom=3, 
                           center = {"lat": -10.704459239815383, "lon": -50.771587751708005},
                           opacity=0.5,
                           hover_name='Município'
                          )
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
